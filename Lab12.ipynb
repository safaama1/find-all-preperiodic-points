# %%
import pandas as pd

# %%
df = pd.read_csv("./survey_results_public.csv")
schema =pd.read_csv("./survey_results_schema.csv")

# %%
# a
filt_israel = df["Country"]  == "Israel"
df.loc[filt_israel , "Country"].count()
# Out:
# 952

# %%
# b
filt_israel = df["Country"]  == "Israel"
df.loc[filt_israel , "ConvertedComp"].mean()
# Out:
# 94944.37651122625

# %%
# b
filt_israel = df["Country"]  == "Israel"
df.loc[filt_israel , "ConvertedComp"].median()
# Out:
# 90720.0

# %%
# c
filt_python =  df["LanguageWorkedWith"].str.contains('Python',na=False)
num_python_developers = df.loc[filt_python,"LanguageWorkedWith"].count()
num_all_developers = df["LanguageWorkedWith"].count()
avg = num_python_developers / num_all_developers
avg
# Out:
# 0.41616325411960853

# %%
# d
salary_more_70000 = df["ConvertedComp"] >70000
df.loc[salary_more_70000,"ConvertedComp"].count()
# Out:
# 22289

# %%
# e
salary_less_israel = (df["ConvertedComp"] <70000)&(df["Country"]  == "Israel")
df.loc[salary_less_israel,"ConvertedComp"].count()
# Out:
# 190

# %%
# f
df.hist(column="Age")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f927dd9c700>]],
#       dtype=object)
